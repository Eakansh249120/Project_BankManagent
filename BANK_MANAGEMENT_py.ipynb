# %% [markdown]
# <a href="https://colab.research.google.com/github/Eakansh249120/Project_BankManagent/blob/main/BANK_MANAGEMENT_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tkinter import *
from tkinter import messagebox
import sqlite3

conn=sqlite3.connect("system.db")
conn1=sqlite3.connect("record.db")
win=Tk()
win.title("BANK MANAGEMNET SOFTWARE")








#for customer
win.geometry("500x500")
passs=StringVar()
namee=StringVar()
account=StringVar()
nameee=StringVar()
fathername=StringVar()
emailid=StringVar()
contactno=StringVar()
address=StringVar()
dateofb=StringVar()
custdel=StringVar()
regidate=StringVar()
#for employee
empname=StringVar()
empid=StringVar()
empgender=StringVar()
empcontact=StringVar()
empposition=StringVar()
empemail=StringVar()
empdel=StringVar()
#for complaints
customer123=StringVar()
date123=StringVar()
address123=StringVar()
email123=StringVar()
contactno123=StringVar()
complaint123=StringVar()
suggesstion123=StringVar()
#for banking
initamount=StringVar()
amount=StringVar()
deposit=StringVar()
dateofdeposit=StringVar()
balance=StringVar()
dateofwithdrwal=StringVar()
wtamount=StringVar()
#code for back button
conn.execute("create table if not exists transactions1(account char(40) not null,date char(40) not null,deposit char(40) not null,withdraw char(40) not null,balance char(40) not null)")
def back1():
    f1.grid(row=0,column=0)
    f2.grid_forget()

def back2():
    f2.grid(row=0,column=0)
    f3.grid_forget()

def back3():
    f4.grid_forget()
    f3.grid(row=0,column=0)

def back4():
    f5.grid_forget()
    f3.grid(row=0 , column=0)

def back5():
    f6.grid_forget()
    f2.grid(row=0 , column=0)

def back6():
    f7.grid_forget()
    f6.grid(row=0,column=0)

def back7():
    f9.grid_forget()
    f3.grid(row=0,column=0)

def back8():
    f6.grid_forget()
    f10.grid(row=0,column=0)

def signup():

    pass1=passs.get()
    name1=namee.get()
    conn.execute("create table if not exists login(username char(40) not null , password char(40) not null)")
    conn.execute("insert into login values(?,?)",(name1,pass1,))
    conn.commit()
    messagebox.showinfo(message="SIGN UP COMPLETED")
def login():

    pass1=passs.get()
    name1=namee.get()
    show=conn.execute("select * from login where username=? and password=?" ,(name1,pass1,))
    if show.fetchone() is None:
        messagebox.showinfo(message="PLESE ENTER RIGHT PASSWORD")
    else:
        messagebox.showinfo(message="SUCCEEFULLY LOGIN")
        f1.grid_forget()
        f2.grid(row=0 , column=0)
def customerrecord():

    f2.grid_forget()
    f3.grid(row=0 , column=0)
def reset():

    passs.set(" ")
    namee.set(" ")
def newcustomer():

    f3.grid_forget()
    f4.grid(row=0 , column=0)
    name2=nameee.get()
    account1=account.get()
    fathername1=fathername.get()
    emailid1=emailid.get()
    contactno1=contactno.get()
    address1=address.get()
    dateofb1=dateofb.get()
    initamount1=initamount.get()
    regidate1=regidate.get()
    conn.execute("create table if not exists newcustomer1(account int(10) not null, name char(40) not null ,fathername char(40) not null,emailid char(100) not null,contactno int(10) not null,address char(100) not null,birthday char(20) not  null ,initial_ammount int(10) not null)")
    conn.execute("insert into newcustomer1 values(?,?,?,?,?,?,?,?)",(account1,name2,fathername1,emailid1,contactno1,address1,dateofb1,initamount1,))


    conn.commit()

def customerupdate():
    nameee1=nameee.get()
    account1=account.get()
    fathername1=fathername.get()
    emailid1=emailid.get()
    contactno1=contactno.get()
    address1=address.get()
    dateofb1=dateofb.get()
    conn.execute("update newcustomer1 set name=?,fathername=?,emailid=?,contactno=?,address=?,birthday=? where account=?",(nameee1,fathername1,emailid1,contactno1,address1,dateofb1,account1,))
    conn.commit()
    messagebox.showinfo(message="UPDATE SUCCESSFUL")



def delete():

    ac=account.get()
    conn.execute("delete from newcustomer1 where account=?",(ac,))
    messagebox.showinfo(message="RECORD DELETED")
    conn.commit()

def empdelete():
    empid1=empid.get()

    conn.execute("delete from employeerecord2345 where id=?",(empid1,))
    messagebox.showinfo(message="RECORD DELETED")

def empdelframeback():
    f8.grid_forget()
    f6.grid(row=0,column=0)

def delete1():

    f3.grid_forget()
    f5.grid(row=0 , column=0)

def empdelframe():
    f8.grid(row=0,column=0)
    f6.grid_forget()

def employeeframe():
    f2.grid_forget()
    f6.grid(row=0 , column=0)

def customerupdatefr():
    f3.grid_forget()
    f9.grid(row=0 , column=0)



def employeeregister():
    f6.grid_forget()
    f7.grid(row=0,column=0)
    name2=empname.get()
    id2=empid.get()
    gender2=empgender.get()
    contact2=empcontact.get()
    position2=empposition.get()
    email2=empemail.get()
    conn.execute("create table if not exists employeerecord2345(name char(40) not null,id int(40) not null,gender char(20) not null,contact int(40) not null,position char(20) not null ,email char(40) not null)")
    conn.execute("insert into employeerecord2345 values(?,?,?,?,?,?)",(name2,id2,gender2,contact2,position2,email2,))
    conn.commit()

def employeeupdate():
    empname1=empname.get()
    empid1=empid.get()
    empgender1=empgender.get()
    empcontact1=empcontact.get()
    empposition1=empposition.get()
    empemail1=empemail.get()
    conn.execute("update employeerecord2345 set name=?,gender=?,contact=?,position=?,email=? where id=?",(empname1,empgender1,empcontact1,empposition1,empemail1,empid1))
    conn.commit()
    messagebox.showinfo(message="RECORD UPDATED")

def empupdateback():
    f10.grid_forget()
    f6.grid(row=0,column=0)

def customersearch():

    account1=account.get()
    show=conn.execute("select * from newcustomer1 where account=?",(account1,))
    for row in show:
        print("NAME " ,row[1])
        print("FATHER NAME ",row[2])
        print("EMAIL ID ",row[3])
        print("CONTACT NUMBER ",row[4])
        print("ADDRESS ",row[5])
        print("BIRTH DATE ",row[6])
        print("INITIAL AMOUNT ",row[7])

def cussearchback():
    f11.grid_forget()
    f3.grid(row=0,column=0)

def cussearchfr():
    f3.grid_forget()
    f11.grid(row=0,column=0)

def employesearch():
    empid1=empid.get()
    show=conn.execute("select * from employeerecord2345 where id=?",(empid1,))
    for row in show:
        print("NAME ",row[0])
        print("GENDER" , row[2])
        print("CONTACT" , row[3])
        print("POSITION ",row[4])
        print("EMAIL ID ",row[5])

def employeeseachfr():
    f6.grid_forget()
    f12.grid(row=0,column=0)

def employeesearchback():
    f12.grid_forget()
    f6.grid(row=0,column=0)

def customerrecord1():
    show=conn.execute("select * from newcustomer1")
    for row in show:
        print(row[0]," ",row[1]," ",row[2]," ",row[3]," ",row[4]," ",row[5]," ",row[6]," ",row[7])

def customerrecordfr():
    f3.grid_forget()
    f13.grid(row=0,column=0)

def customerrecordback():
    f13.grid_forget()
    f3.grid(row=0,column=0)

def employeeshowall():
    show=conn.execute("select * from employeerecord2345")
    for row in show:
        print(row[0]," ",row[1]," ",row[2]," ",row[3]," ",row[4]," ",row[5])

def employeeshowallfr():
    f6.grid_forget()
    f14.grid(row=0,column=0)

def employeeshowallback():
    f14.grid_forget()
    f6.grid(row=0,column=0)

def complaints():
    customer1=customer123.get()
    date1=date123.get()
    address1=address123.get()
    email1=email123.get()
    contact1=contactno123.get()
    complaint1=complaint123.get()
    sugg1=suggesstion123.get()
    conn.execute("create table if not exists complaints1(name char(20) not null,date char(20) not null,address char(40) not null,email char(20) not null,contact int(20) not null,complaint char(500) not null,suggestion char(50) not null)")
    conn.execute("insert into complaints1 values(?,?,?,?,?,?,?)",(customer1,date1,address1,email1,contact1,complaint1,sugg1))
    conn.commit()

def complaintsfr():
    f2.grid_forget()
    f15.grid(row=0,column=0)

def complaintsfrback():
    f15.grid_forget()
    f2.grid(row=0,column=0)

def complaintsearch():
    cust1=customer123.get()
    show=conn.execute("select * from complaints1 where name=?",(cust1,))
    for row in show:
        print(row[0]," ",row[1]," ",row[2]," ",row[3]," ",row[4]," ",row[5]," ",row[6])

def complanintupdate():
    customer1=customer123.get()
    date1=date123.get()
    address1=address123.get()
    email1=email123.get()
    contact1=contactno123.get()
    complaint1=complaint123.get()
    sugg1=suggesstion123.get()
    conn.execute("update complaints set name=?,date=?,address=?,email=?,contact=?,complaint=?,suggestion=?",(customer1,date1,address1,email1,contact1,complaint1,sugg1))

    conn.commit()

def depositsearch():
    acc1=account.get()
    date12=dateofdeposit.get()
    deposit12=deposit.get()
    balance12=balance.get()
    initamount1=initamount.get()

    show=conn.execute("select * from newcustomer1 where account=?",(acc1,))
    for row in show:
        amount.set(row[7])
        amounts=amount.get()

        balance13=int(deposit12)+int(amounts)
        balance.set(balance13)


    conn.execute("create table if not exists transactions1(account char(40) not null,date char(40) not null,deposit char(40) not null,withdraw char(40) not null,balance char(40) not null)")
    conn.execute("insert into transactions1 values(?,?,?,?,?)",(acc1,date12,date12,deposit12,wtamount12,balance12))
    conn.execute("update newcustomer1 set initial=? where account=?",(balance13,acc1,))
    conn.commit()


def withdraw():
    acc1=account.get()
    date12=dateofdeposit.get()
    wtamount12=wtamount.get()
    balance12=balance.get()


    show=conn.execute("select * from newcustomer1 where account=?",(acc1,))
    for row in show:
        amount.set(row[7])
        amounts=amount.get()
        balance13=int(amounts)-int(wtamount12)
        balance.set(balance13)
        row[7].set(balance13)

    conn.execute("create table if not exists transactions1(account char(40) not null,date char(40) not null,deposit char(40) not null,withdraw char(40) not null,balance char(40) not null)")
    conn.execute("insert into transactions1 values(?,?,?,?,?)",(acc1,date12,deposit12,wtamount12,balance12))
    conn.commit()






def depositframe():
    f3.grid_forget()
    f16.grid(row=0,column=0)

def dateofwithdrwal():
    f3.grid_forget()
    f17.grid(row=0,column=0)

f1=Frame(win)
f1.grid(row=0 , column=0)
l1=Label(f1 , text="BANKING SYSTEM")
l2=Label(f1 , text="USERNAME")
l3=Label(f1 , text="PASSWORD")
t1=Entry(f1)
t2=Entry(f1, textvariable=namee)
t3=Entry(f1,textvariable=passs)
b1=Button(f1 , text="LOGIN",command=login)
b2=Button(f1 , text="RESET",command=reset)
b3=Button(f1 , text="SIGN UP",command=signup)

l1.grid(row=0,column=2)
l2.grid(row = 1,column=0)
t2.grid(row=1, column=1)
l3.grid(row = 2,column=0)
t3.grid(row=2, column=1)

b1.grid(row=3 , column=0)
b2.grid(row=3 , column=1)
b3.grid(row=3 , column=2)

f2=Frame(win)#
l1=Label(f2 , text="INDEX").grid(row=0 , column=2)
B1=Button(f2 , text="CUSTOMER RECORD",command=customerrecord).grid(row=1 , column=2)
B2=Button(f2 , text="EMPLOYEE RECORD",command=employeeframe).grid(row=2 , column=2)
B3=Button(f2 , text="COMPLAINTS",command=complaintsfr).grid(row=3 , column=2)

B5=Button(f2 , text="EXIT").grid(row=5 , column=2)
B6=Button(f2,text="BACK",command=back1).grid(row=6,column=2)


f3=Frame(win)#frame for customer record
b1=Button(f3 , text="ADD NEW CUSTOMER",command=newcustomer).grid(row=1 , column=0)
b2=Button(f3 , text="DELETE CUSTOMER",command=delete1).grid(row=2 , column=0)
b3=Button(f3 , text="UPDATE CUSTOMER",command=customerupdatefr).grid(row=3 , column=0)
b4=Button(f3 , text="SEARCH CUSTOMER",command=cussearchfr).grid(row=4 , column=0)
b5=Button(f3 , text="SHOW ALL CUSTOMER",command=customerrecordfr).grid(row=5 , column=0)
b6=Button(f3 , text="WITHDRAWL",command=dateofwithdrwal).grid(row=6,column=0)
b7=Button(f3 , text="DEPOSIT",command=depositframe).grid(row=6 , column=1)
b8=Button(f3 , text="BACK" , command=back2).grid(row=7,column=0)

f4=Frame(win)#frame for add new customer
l1=Label(f4 , text="ACCOUNT NUMBER").grid(row=0 , column=0)
t1=Entry(f4,textvariable=account).grid(row=0 , column=1)
l2=Label(f4 , text="NAME").grid(row=1 , column=0)
t2=Entry(f4,textvariable=nameee).grid(row=1 , column=1)
l3=Label(f4 , text="FATHER NAME").grid(row=2 , column=0)
t3=Entry(f4,textvariable=fathername).grid(row=2 , column=1)
l4=Label(f4 , text="EMAIL ID ").grid(row=3 , column=0)
t4=Entry(f4,textvariable=emailid).grid(row=3 , column=1)
l8=Label(f4 , text="DATE OF REGISTRATION(DD/MM/YYYY)").grid(row=4,column=0)
t8=Entry(f4 , textvariable=regidate).grid(row=4,column=1)
l9=Label(f4 , text="INITIAL AMOUNT").grid(row=5,column=0)
t9=Entry(f4 , textvariable=initamount).grid(row=5,column=1)
l5=Label(f4 , text="CONTACT NO").grid(row=6 , column=0)
t5=Entry(f4,textvariable=contactno).grid(row=6 , column=1)
l6=Label(f4 , text="ADDRESS").grid(row=7 , column=0)
t6=Entry(f4,textvariable=address).grid(row=7 , column=1)
l7=Label(f4 , text="DATE OF BIRTH").grid(row=8 , column=0)
t7=Entry(f4,textvariable=dateofb).grid(row=8 , column=1)
b1=Button(f4,text="SUBMIT",command=newcustomer).grid(row=9,column=0)
b2=Button(f4 , text="BACK" , command=back3).grid(row=9,column=1)

f5=Frame(win)#frame for customer delete

l2=Label(f5,text="ACCOUNT NUMBER").grid(row=1,column=0)
t2=Entry(f5,textvariable=account).grid(row=1,column=1)
b1=Button(f5, text="DELETE",command=delete).grid(row=2,column=1)
b2=Button(f5 , text="BACK" , command=back4).grid(row=3 , column=1)

f6=Frame(win)#frame for employee index
l1=Label(f6,text="EMPLOYEE SECTION").grid(row=0,column=0)
b1=Button(f6 , text="NEW EMPLOYEE REGISTRATION",command=employeeregister).grid(row=1 , column=0)
b2=Button(f6 , text="EMPLOYEE RECORD DELETE",command=empdelframe).grid(row=2 , column=0)
b3=Button(f6 , text="EMPLOYEE RECORD UPDATE",command=back8).grid(row=3 , column=0)
b4=Button(f6 , text="EMPLOYEE SALARY MANAGEMNET").grid(row=4 , column=0)
b5=Button(f6 , text="EMPLOYEE DETAILS",command=employeeseachfr).grid(row=5 , column=0)
b6=Button(f6 , text="EMPLOYEE DATA",command=employeeshowallfr).grid(row=6 , column=0)
b8=Button(f6 , text="BACK",command=back5).grid(row=7 , column=0)

f7=Frame(win)#frame for employee registration
l1=Label(f7 , text="NAME").grid(row=1,column=0)
t1=Entry(f7,textvariable=empname ).grid(row=1,column=1)
l1=Label(f7 , text="EMPLOYEE ID").grid(row=2,column=0)
t1=Entry(f7 ,textvariable=empid).grid(row=2,column=1)
l1=Label(f7 , text="GENDER").grid(row=3,column=0)
t1=Entry(f7,textvariable=empgender ).grid(row=3,column=1)
l1=Label(f7 , text="CONTACT NO ").grid(row=4,column=0)
t1=Entry(f7,textvariable=empcontact ).grid(row=4,column=1)
l1=Label(f7 , text="POSITION").grid(row=5,column=0)
t1=Entry(f7,textvariable=empposition ).grid(row=5,column=1)
l1=Label(f7 , text="EMAIL ID").grid(row=6,column=0)
t1=Entry(f7,textvariable=empemail).grid(row=6,column=1)
b1=Button(f7,text="SUBMIT",command=employeeregister).grid(row=7,column=0)
b2=Button(f7,text="BACK",command=back6).grid(row=7,column=1)

f8=Frame(win)#frame for employee record delete
l2=Label(f8 , text="EMPLOYEE RECORD DELETE WINDOW").grid(row=0,column=0)
l1=Label(f8 , text="ENTER EMPLOYEE ID").grid(row=1,column=0)
t1=Entry(f8 , textvariable=empid).grid(row=1,column=1)
b1=Button(f8 , text="DELETE",command=empdelete).grid(row=2,column=0)
b2=Button(f8 , text="BACK",command=empdelframeback).grid(row=2,column=1)

f9=Frame(win)#frame for customer record update

l2=Label(f9 , text="CUSTOMER RECORD UPDATE WINDOW").grid(row=0,column=0)
l3=Label(f9 , text="ACCOUNT NO").grid(row=1,column=0)
t3=Entry(f9 , textvariable=account).grid(row=1,column=1)
l1=Label(f9 , text="NAME").grid(row=2,column=0)
t1=Entry(f9,textvariable=nameee ).grid(row=2,column=1)
l3=Label(f9 , text="FATHER NAME").grid(row=3 , column=0)
t3=Entry(f9,textvariable=fathername).grid(row=3 , column=1)
l4=Label(f9 , text="EMAIL ID ").grid(row=4 , column=0)
t4=Entry(f9,textvariable=emailid).grid(row=4 , column=1)
l8=Label(f9 , text="DATE OF REGISTRATION(DD/MM/YYYY)").grid(row=5,column=0)
t8=Entry(f9 , textvariable=regidate).grid(row=5,column=1)
l5=Label(f9 , text="CONTACT NO").grid(row=6 , column=0)
t5=Entry(f9,textvariable=contactno).grid(row=6 , column=1)
l6=Label(f9 , text="ADDRESS").grid(row=7 , column=0)
t6=Entry(f9,textvariable=address).grid(row=7 , column=1)
l7=Label(f9 , text="DATE OF BIRTH").grid(row=8 , column=0)
t7=Entry(f4,textvariable=dateofb).grid(row=8 , column=1)

b1=Button(f9 , text="UPDATE",command=customerupdate).grid(row=10 , column=0)
b2=Button(f9 , text="BACK" , command=back7).grid(row=10,column=1)

f10=Frame(win)#frame for employee update

l1=Label(f10 , text="EMPLOYEE UPDATE WINDOW").grid(row=0,column=0)
l2=Label(f10 , text="ID").grid(row=1,column=0)
t1=Entry(f10 , textvariable=empid).grid(row=1,column=1)
l2=Label(f10 , text="NAME").grid(row=2,column=0)
t1=Entry(f10 , textvariable=empname).grid(row=2,column=1)
l2=Label(f10 , text="GENDER").grid(row=3,column=0)
t1=Entry(f10 , textvariable=empgender).grid(row=3,column=1)
l2=Label(f10 , text="CONTACT NO").grid(row=4,column=0)
t1=Entry(f10 , textvariable=empcontact).grid(row=4,column=1)
l2=Label(f10 , text="POSITION").grid(row=5,column=0)
t1=Entry(f10 , textvariable=empposition).grid(row=5,column=1)
l2=Label(f10 , text="EMAIL ID").grid(row=6,column=0)
t1=Entry(f10 , textvariable=empemail).grid(row=6,column=1)
b1=Button(f10 , text="UPDATE",command=employeeupdate).grid(row=7,column=0)
b2=Button(f10 , text="BACK",command=empupdateback).grid(row=7,column=1)

f11=Frame(win)#frame for customer search
l1=Label(f11,text="CUSTOMER SEARCH WINDOW").grid(row=0,column=0)
l2=Label(f11,text="ACCOUNT NUNMBER").grid(row=1,column=0)
t2=Entry(f11,textvariable=account).grid(row=1,column=1)
b1=Button(f11,text="SEARCH",command=customersearch).grid(row=2,column=0)
b2=Button(f11,text="BACK",command=cussearchback).grid(row=2,column=1)

f12=Frame(win)#frame for employee search
l1=Label(f12 , text="EMPLOYEE SEARCH WINDOW").grid(row=0,column=0)
l2=Label(f12 , text="EMPLOYEE ID").grid(row=1,column=0)
t2=Entry(f12 , textvariable=empid).grid(row=1,column=1)
b1=Button(f12,text="SEARCH",command=employesearch).grid(row=2,column=0)
b2=Button(f12,text="BACK",command=employeesearchback).grid(row=2,column=1)

f13=Frame(win)#frame for customer record
l1=Label(f13 , text="CUSTOMER DATA WINDOW").grid(row=0,column=0)
B1=Button(f13 , text="SHOW ALL RECORD",command=customerrecord1).grid(row=5,column=0)
B2=Button(f13 , text="BACK",command=customerrecordback).grid(row=5,column=2)

f14=Frame(win)#frame for employee record
l1=Label(f14 , text="EMPLOYEE DATA WINDOW").grid(row=0,column=0)
B1=Button(f14 , text="SHOW ALL RECORD",command=employeeshowall).grid(row=5,column=0)
B2=Button(f14 , text="BACK",command=employeeshowallback).grid(row=5,column=2)

f15=Frame(win)#frame for complaints
l1=Label(f15 , text="COMPLAINT WINDOW").grid(row=0,column=0)
l2=Label(f15 , text="NAME").grid(row=1,column=0)
t2=Entry(f15 , textvariable=customer123).grid(row=1,column=1)
l3=Label(f15 , text="DATE OF COMPLAINT(DD/MM/YYYY").grid(row=2,column=0)
t3=Entry(f15 , textvariable=date123).grid(row=2,column=1)
l4=Label(f15 , text="ADDRESS").grid(row=3,column=0)
t4=Entry(f15 , textvariable=address123).grid(row=3,column=1)
l5=Label(f15 , text="CONTACT NO").grid(row=4,column=0)
t5=Entry(f15 , textvariable=contactno123).grid(row=4,column=1)
l6=Label(f15 , text="EMAIL").grid(row=5,column=0)
t6=Entry(f15 , textvariable=email123).grid(row=5,column=1)
l7=Label(f15 , text="COMPLAINT").grid(row=6,column=0)
t7=Entry(f15 , textvariable=complaint123).grid(row=6,column=1)
l7=Label(f15 , text="SUGGESTION").grid(row=7,column=0)
t7=Entry(f15 , textvariable=suggesstion123).grid(row=7,column=1)
b1=Button(f15,text="REGISTER",command=complaints).grid(row=8,column=0)
b2=Button(f15,text="BACK",command=complaintsfrback).grid(row=9,column=1)
b3=Button(f15 , text="SEARCH",command=complaintsearch).grid(row=8,column=2)
b4=Button(f15 , text="UPDATE",command=complanintupdate).grid(row=8,column=1)

f16=Frame(win)#frame for deposit
l1=Label(f16,text="ACCOUNT NUMBER").grid(row=0,column=0)
t1=Entry(f16,textvariable=account).grid(row=0,column=1)
l4=Label(f16,text="DATE OF TRANSACTION").grid(row=1,column=0)
t4=Entry(f16,textvariable=dateofdeposit).grid(row=1,column=1)
l2=Label(f16,text="AMOUNT").grid(row=2,column=0)
t1=Entry(f16,textvariable=amount).grid(row=2,column=1)
l3=Label(f16,text="DEPOSIT AMOUNT").grid(row=3,column=0)
t3=Entry(f16,textvariable=deposit).grid(row=3,column=1)
l3=Label(f16,text="BALANCE AMOUNT").grid(row=4,column=0)
t3=Entry(f16,textvariable=balance).grid(row=4,column=1)
b1=Button(f16,text="SEARCH",command=depositsearch).grid(row=5,column=0)

f17=Frame(win)#frame for withdrawl
l1=Label(f17,text="ACCOUNT NUMBER").grid(row=0,column=0)
t1=Entry(f17,textvariable=account).grid(row=0,column=1)
l1=Label(f17,text="DATE OF WITHDRAWL").grid(row=1,column=0)
t1=Entry(f17,textvariable=dateofwithdrwal).grid(row=1,column=1)
l1=Label(f17,text="WITHDRAW AMOUNT").grid(row=2,column=0)
t1=Entry(f17,textvariable=wtamount).grid(row=2,column=1)
l2=Label(f17,text="AMOUNT").grid(row=3,column=0)
t1=Entry(f17,textvariable=amount).grid(row=3,column=1)

l3=Label(f17,text="BALANCE AMOUNT").grid(row=4,column=0)
t3=Entry(f17,textvariable=balance).grid(row=4,column=1)
b1=Button(f17,text="WITHDRAW",command=withdraw).grid(row=5,column=0)
